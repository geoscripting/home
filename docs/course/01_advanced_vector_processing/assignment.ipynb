# %% [markdown]
# # Assignment: Advanced Geo Data Processing

# %% [markdown]
# ## 1. Object-orientied programming

# %%
def run():
	pass

# %% [markdown]
# ## 2.2 Python modules for vector data processing

# %% [markdown]
# ## 2.3. Python modules for raster data processing

# %% [markdown]
# ## 2.4. Comparing runtimes
